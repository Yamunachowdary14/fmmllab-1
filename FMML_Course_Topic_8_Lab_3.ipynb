# %% [markdown]
# <a href="https://colab.research.google.com/github/Yamunachowdary14/fmmllab-1/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-26 14:12:02--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   117MB/s    in 0.6s
#
# 2024-03-26 14:12:03 (117 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 35248  cs/0205013v1  We study algorithms for computing stable model...    cs
# 32939  1511.06333v4  The sparsity of signals in a transform domain ...    cs
# 1877   1802.02550v3  Amortized variational inference (AVI) replaces...  stat
# 16532  1703.09817v3  A significant source of errors in Automatic Sp...    cs
# 7796   1803.04204v1  This paper studies semiparametric contextual b...  stat
# ...             ...                                                ...   ...
# 32864  1509.07927v1  We study stochastic linear optimization proble...    cs
# 11676  1609.05959v1  General predictive models do not provide a mea...  stat
# 26309  1609.08078v4  This paper presents a robust regression approa...    cs
# 20571  1607.00428v1  This paper details the implementation of an al...    cs
# 36102   1406.6045v1  Video Surveillance is a fast evolving field of...    cs
#
#                                                    title  year  \
# 35248  Computing stable models: worst-case performanc...  2002
# 32939  Efficient Sum of Outer Products Dictionary Lea...  2015
# 1877             Semi-Amortized Variational Autoencoders  2018
# 16532  Learning Similarity Functions for Pronunciatio...  2017
# 7796                   Semiparametric Contextual Bandits  2018
# ...                                                  ...   ...
# 32864   Algorithms for Linear Bandits on Polyhedral Sets  2015
# 11676              Conformalized Kernel Ridge Regression  2016
# 26309  Robust Regression For Image Binarization Under...  2016
# 20571  Situated Structure Learning of a Bayesian Logi...  2016
# 36102  Cognitive Surveillance: Why does it never appe...  2014
#
#                                                 keywords
# 35248  [algorithms, computing, propositional, estimat...
# 32939  [transform, dictionary, exploited, application...
# 1877   [amortized, variational, inference, inference,...
# 16532  [significant, automatic, recognition, pronunci...
# 7796   [semiparametric, contextual, generalization, s...
# ...                                                  ...
# 32864  [stochastic, optimization, dimensional, polyhe...
# 11676  [predictive, confidence, predictions, assumpti...
# 26309  [regression, binarization, significant, backgr...
# 20571  [implementation, algorithm, automatically, gen...
# 36102  [surveillance, development, terrorism, vandali...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 35248    [algorithms, computing, propositional, estimat...
# 32939    [transform, dictionary, exploited, application...
# 1877     [amortized, variational, inference, inference,...
# 16532    [significant, automatic, recognition, pronunci...
# 7796     [semiparametric, contextual, generalization, s...
#                                ...
# 14446    [describes, estimating, conditional, probabili...
# 21784    [synthetic, optimization, designing, character...
# 21506    [investigate, statistics, homogeneity, reprodu...
# 10495    [effective, connectome, inference, algorithm, ...
# 24627    [apictorial, collection, algebraic, representa...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8755 words.
# Out of those 4564 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="b6aa19b1-8b9e-4ef5-a278-1473d267c245" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b6aa19b1-8b9e-4ef5-a278-1473d267c245")) {                    Plotly.newPlot(                        "b6aa19b1-8b9e-4ef5-a278-1473d267c245",                        [{"x":["estimates","algorithm","algorithms","performance","computing","propositional","asymptotically","efficient","convergence","synthesis","compressed","adaptation","promising","alternating","experiments","representation","application","dictionary","computations","resulting","investigates","denoising","compression","coordinate","typically","approaches","exploited","transform","reconstruction","dominated","analytical","aggregate","expensive","dictionaries","penalized","computationally","approximating","furthermore","solutions","applications","minimization","numerical","methodologies","optimization","generation","amortized","suboptimal","differentiable","generative","outperforms","stochastic","procedure","crucially","inference","phenomenon","variational","autoencoders","autoregressive","parameters","baselines","posterior","experiencing","initialize","empirical","neighborhoods","demonstrate","generalizes","classification","graphical","automatic","pronunciations","significant","functions","efficiency","pronunciation","different","dynamically","recurrent","similarity","conversational","recognition","variations","spontaneous","predicting","switchboard","canonical","technically","contextual","martingales","semiparametric","estimator","independent","evaluation","concentration","inequalities","normalized","generalization","confounded","unconfounded","outperform","confounding","dimensional","collected","accompanied","recognizes","extensive","continuous","movements","constructed","correlated","physiological","intensities","activities","significantly","exclusively","occlusions","audiovisual","specifically","relationships","probabilistic","framework","recognize","especially","experimental","challenging","inferring","impressive","activated","performed","observations","recognizing","preferable","approximate","projected","techniques","quantization","important","estimation","nonlinear","candidate","therefore","particular","combining","sublinear","estimators","identified","projections","sufficient","recommended","advantage","effective","similarities","practical","quantizing","information","retrieval","independently","containing","adaptability","granularity","documents","thousands","representations","extracting","structures","scientific","constructing","drastically","encourage","appropriate","technique","methodology","selection","parameter","multitask","accurately","membership","formulate","structure","regularizer","iteration","description","iterative","incrementally","detection","constructs","extremely","monitoring","replacement","computation","recasting","extensibility","programming","development","distributed","implications","environment","facilities","ontologies","arbitrary"],"y":[62,838,607,812,132,25,11,389,97,40,27,66,106,23,610,366,263,41,32,163,26,39,50,26,105,409,35,65,100,9,20,15,59,12,10,101,16,149,133,427,68,79,17,299,133,2,10,23,143,280,124,122,10,222,29,60,16,5,226,53,33,4,5,164,11,541,39,506,64,226,2,247,216,138,5,721,30,144,135,14,381,85,9,91,6,20,1,53,2,1,24,116,252,9,7,25,106,0,0,84,2,188,78,7,9,166,107,23,65,42,5,6,47,282,5,19,2,167,69,163,526,43,136,375,290,30,21,9,122,80,38,7,99,13,354,15,351,211,60,51,166,262,103,9,14,54,27,67,4,97,258,29,141,3,711,96,43,56,8,12,84,29,236,54,146,38,53,10,13,79,259,80,142,115,4,72,20,48,344,24,35,74,69,19,348,15,50,36,8,124,1,4,110,120,118,28,133,5,22,83],"type":"bar"},{"x":["estimates","algorithm","algorithms","performance","computing" ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4564,), (4564, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8083333333333333

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	experimental (0.13368983957219252)
# 	knowledge (0.1322638146167558)
# 	segmentation (0.0680926916221034)
# 	automatic (0.08057040998217468)
# 	architecture (0.08413547237076649)
# 	information (0.253475935828877)
# 	detection (0.12406417112299466)
# 	different (0.2570409982174688)
# 	convolutional (0.13368983957219252)
# 	recognition (0.1358288770053476)
#
# Some Statistics words are:
# 	optimization (0.19649122807017544)
# 	distribution (0.17644110275689223)
# 	estimation (0.17142857142857143)
# 	statistical (0.1593984962406015)
# 	stochastic (0.1443609022556391)
# 	theoretical (0.1573934837092732)
# 	algorithm (0.4020050125313283)
# 	inference (0.20100250626566415)
# 	dimensional (0.1974937343358396)
# 	regression (0.1799498746867168)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="9648ed88-0b96-4f17-b506-d51ec5e26e95" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9648ed88-0b96-4f17-b506-d51ec5e26e95")) {                    Plotly.newPlot(                        "9648ed88-0b96-4f17-b506-d51ec5e26e95",                        [{"x":["estimates","algorithm","algorithms","performance","computing","propositional","asymptotically","efficient","convergence","synthesis","compressed","adaptation","promising","alternating","experiments","representation","application","dictionary","computations","resulting","investigates","denoising","compression","coordinate","typically","approaches","exploited","transform","reconstruction","dominated","analytical","aggregate","expensive","dictionaries","penalized","computationally","approximating","furthermore","solutions","applications","minimization","numerical","methodologies","optimization","generation","amortized","suboptimal","differentiable","generative","outperforms","stochastic","procedure","crucially","inference","phenomenon","variational","autoencoders","autoregressive","parameters","baselines","posterior","experiencing","initialize","empirical","neighborhoods","demonstrate","generalizes","classification","graphical","automatic","pronunciations","significant","functions","efficiency","pronunciation","different","dynamically","recurrent","similarity","conversational","recognition","variations","spontaneous","predicting","switchboard","canonical","technically","contextual","martingales","semiparametric","estimator","independent","evaluation","concentration","inequalities","normalized","generalization","confounded","unconfounded","outperform","confounding","dimensional","collected","accompanied","recognizes","extensive","continuous","movements","constructed","correlated","physiological","intensities","activities","significantly","exclusively","occlusions","audiovisual","specifically","relationships","probabilistic","framework","recognize","especially","experimental","challenging","inferring","impressive","activated","performed","observations","recognizing","preferable","approximate","projected","techniques","quantization","important","estimation","nonlinear","candidate","therefore","particular","combining","sublinear","estimators","identified","projections","sufficient","recommended","advantage","effective","similarities","practical","quantizing","information","retrieval","independently","containing","adaptability","granularity","documents","thousands","representations","extracting","structures","scientific","constructing","drastically","encourage","appropriate","technique","methodology","selection","parameter","multitask","accurately","membership","formulate","structure","regularizer","iteration","description","iterative","incrementally","detection","constructs","extremely","monitoring","replacement","computation","recasting","extensibility","programming","development","distributed","implications","environment","facilities","ontologies","arbitrary","abstraction","potential","programmatic","integration","dynamical","expression","necessity","incorporate","necessary","consequence","attractor","convexity","mechanics","classical","neighborhood","formulation","hamiltonian","functional","condition","consideration","repositories","mathematical","stability","formalization","engineering","mathematics","formalized","knowledge","underlying","electrical","correction","simultaneously","corrected","consecutive","streaming","optimizing","keyframes","incorporated","negligible","environments","estimated","quantitative","reconstructed","consistent","automatically","reasonable","integrated","implement","conditional","architectures","independence","procedures","consuming","completi ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	confounded
# 	unconfounded
# 	dendrogram
# 	initiates
# 	memberships
# 	regularised
# 	quadrature
# 	integrands
# 	quadratures
# 	volatility
# 	asymmetries
# 	nesterovs
# 	minibatches
# 	polymorphisms
# 	parallelisation
# 	informally
# 	privately
# 	inclusions
# 	substantive
# 	proportionality
# Some words which never appear in Statistics papers:
# 	propositional
# 	pronunciations
# 	conversational
# 	switchboard
# 	recognizes
# 	occlusions
# 	facilities
# 	abstraction
# 	keyframes
# 	vibration
# 	impairments
# 	hazardous
# 	installed
# 	smartphone
# 	prospector
# 	referential
# 	concatenation
# 	incapable
# 	morphologically
# 	keypoints

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.066167903354388e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7525
